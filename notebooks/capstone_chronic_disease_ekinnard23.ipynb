# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
e2010 = pd.read_csv(r'/Users/eykin/Desktop/Eddie Documentsls/projects/Chronic_disease_capstone/data/ACSST1Y2010.S0101-Data.csv')
e2011 = pd.read_csv(r'/Users/eykin/Desktop/Eddie Documentsls/projects/Chronic_disease_capstone/data/ACSST1Y2011.S0101-Data.csv')
e2012 = pd.read_csv(r'/Users/eykin/Desktop/Eddie Documentsls/projects/Chronic_disease_capstone/data/ACSST1Y2012.S0101-Data.csv')
e2013 = pd.read_csv(r'/Users/eykin/Desktop/Eddie Documentsls/projects/Chronic_disease_capstone/data/ACSST1Y2013.S0101-Data.csv')
e2014 = pd.read_csv(r'/Users/eykin/Desktop/Eddie Documentsls/projects/Chronic_disease_capstone/data/ACSST1Y2014.S0101-Data.csv')
e2015 = pd.read_csv(r'/Users/eykin/Desktop/Eddie Documentsls/projects/Chronic_disease_capstone/data/ACSST1Y2015.S0101-Data.csv')
e2016 = pd.read_csv(r'/Users/eykin/Desktop/Eddie Documentsls/projects/Chronic_disease_capstone/data/ACSST1Y2016.S0101-Data.csv')
e2017= pd.read_csv(r'/Users/eykin/Desktop/Eddie Documentsls/projects/Chronic_disease_capstone/data/ACSST1Y2017.S0101-Data.csv')
e2018 = pd.read_csv(r'/Users/eykin/Desktop/Eddie Documentsls/projects/Chronic_disease_capstone/data/ACSST1Y2018.S0101-Data.csv')
e2019 = pd.read_csv(r'/Users/eykin/Desktop/Eddie Documentsls/projects/Chronic_disease_capstone/data/ACSST1Y2019.S0101-Data.csv')
e2021 = pd.read_csv(r'/Users/eykin/Desktop/Eddie Documentsls/projects/Chronic_disease_capstone/data/ACSST1Y2021.S0101-Data.csv')
e2022 = pd.read_csv(r'/Users/eykin/Desktop/Eddie Documentsls/projects/Chronic_disease_capstone/data/ACSST1Y2022.S0101-Data.csv')

# %%
alzheimers = pd.read_csv(r'/Users/eykin/Desktop/Eddie Documentsls/projects/Chronic_disease_capstone/data/Alzheimer_s_Disease_and_Healthy_Aging_Indicators__Cognitive_Decline_20240121.csv')
cdi = pd.read_csv(r'/Users/eykin/Desktop/Eddie Documentsls/projects/Chronic_disease_capstone/data/U.S._Chronic_Disease_Indicators__CDI__20240213_x.csv')
tobacco = pd.read_csv(r'/Users/eykin/Desktop/Eddie Documentsls/projects/Chronic_disease_capstone/data/U.S._Chronic_Disease_Indicators__Tobacco_20240121.csv')
# Out:
# C:\Users\eykin\AppData\Local\Temp\ipykernel_28888\1667513141.py:1: DtypeWarning: Columns (16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   alzheimers = pd.read_csv(r'/Users/eykin/Desktop/Eddie Documentsls/projects/Chronic_disease_capstone/data/Alzheimer_s_Disease_and_Healthy_Aging_Indicators__Cognitive_Decline_20240121.csv')
# C:\Users\eykin\AppData\Local\Temp\ipykernel_28888\1667513141.py:2: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   cdi = pd.read_csv(r'/Users/eykin/Desktop/Eddie Documentsls/projects/Chronic_disease_capstone/data/U.S._Chronic_Disease_Indicators__CDI__20240213_x.csv')
# C:\Users\eykin\AppData\Local\Temp\ipykernel_28888\1667513141.py:3: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
arthritis = pd.read_csv(r'/Users/eykin/Desktop/Eddie Documentsls/projects/Chronic_disease_capstone/data/U.S._Chronic_Disease_Indicators__Arthritis_20240121.csv')
asthma = pd.read_csv(r'/Users/eykin/Desktop/Eddie Documentsls/projects/Chronic_disease_capstone/data/U.S._Chronic_Disease_Indicators__Asthma_20240121.csv')
cancer = pd.read_csv(r'/Users/eykin/Desktop/Eddie Documentsls/projects/Chronic_disease_capstone/data/U.S._Chronic_Disease_Indicators__Cancer_20240121.csv')
cardio = pd.read_csv(r'/Users/eykin/Desktop/Eddie Documentsls/projects/Chronic_disease_capstone/data/U.S._Chronic_Disease_Indicators__Cardiovascular_Disease_20240121.csv')
pulmonary = pd.read_csv(r'/Users/eykin/Desktop/Eddie Documentsls/projects/Chronic_disease_capstone/data/U.S._Chronic_Disease_Indicators__Chronic_Obstructive_Pulmonary_Disease_20240121.csv')
diabetes = pd.read_csv(r'/Users/eykin/Desktop/Eddie Documentsls/projects/Chronic_disease_capstone/data/U.S._Chronic_Disease_Indicators__Diabetes_20240121.csv')
mental = pd.read_csv(r'/Users/eykin/Desktop/Eddie Documentsls/projects/Chronic_disease_capstone/data/U.S._Chronic_Disease_Indicators__Mental_Health_20240121.csv')
overarching = pd.read_csv(r'/Users/eykin/Desktop/Eddie Documentsls/projects/Chronic_disease_capstone/data/U.S._Chronic_Disease_Indicators__Overarching_Conditions_20240121.csv')
usccoord = pd.read_csv(r'/Users/eykin/Desktop/Eddie Documentsls/projects/Chronic_disease_capstone/data/us_cities_coordinates.csv')
uscities = pd.read_csv(r'/Users/eykin/Desktop/Eddie Documentsls/projects/Chronic_disease_capstone/data/uscities.csv')
cdc_census = pd.read_csv(r'/Users/eykin/Desktop/Eddie Documentsls/projects/Chronic_disease_capstone/data/CDC_Places_Data_by_Census_Tract.csv')

# %%
cdi_edit = cdi.drop(['DataSource', 'DataValueType', 'LowConfidenceLimit', 'HighConfidenceLimit', 'StratificationCategory2','Stratification2'],axis=1, inplace=False)
cdi_edit_2 = cdi_edit.drop(['StratificationCategory3','Stratification3','StratificationCategoryID2','StratificationID2','StratificationCategoryID3','StratificationID3'], axis= 1, inplace = False)
cdi_edit_2
# Out:
#          YearStart  YearEnd LocationAbbr    LocationDesc  \
# 0             2010     2010           OR          Oregon
# 1             2019     2019           AZ         Arizona
# 2             2019     2019           OH            Ohio
# 3             2019     2019           US   United States
# 4             2015     2015           VI  Virgin Islands
# ...            ...      ...          ...             ...
# 1185671       2020     2020           WY         Wyoming
# 1185672       2020     2020           WY         Wyoming
# 1185673       2017     2017           IA            Iowa
# 1185674       2020     2020           WY         Wyoming
# 1185675       2019     2019           RI    Rhode Island
#
#                           Topic  \
# 0        Cardiovascular Disease
# 1                       Alcohol
# 2                       Alcohol
# 3                       Alcohol
# 4                       Alcohol
# ...                         ...
# 1185671                Diabetes
# ...

# %%
cdi_edit_2['GeoLocation'] = cdi_edit_2['GeoLocation'].astype(str)

# %%
cdi_edit_2['longitude'] = cdi_edit_2['GeoLocation'].apply(lambda x: float(x.split('(')[-1].split()[0]))
cdi_edit_2['latitude'] = cdi_edit_2['GeoLocation'].apply(lambda x: float(x.split()[-1].split(')')[0]))
cdi_edit_2
# Out:
#          YearStart  YearEnd LocationAbbr    LocationDesc  \
# 0             2010     2010           OR          Oregon
# 1             2019     2019           AZ         Arizona
# 2             2019     2019           OH            Ohio
# 3             2019     2019           US   United States
# 4             2015     2015           VI  Virgin Islands
# ...            ...      ...          ...             ...
# 1185671       2020     2020           WY         Wyoming
# 1185672       2020     2020           WY         Wyoming
# 1185673       2017     2017           IA            Iowa
# 1185674       2020     2020           WY         Wyoming
# 1185675       2019     2019           RI    Rhode Island
#
#                           Topic  \
# 0        Cardiovascular Disease
# 1                       Alcohol
# 2                       Alcohol
# 3                       Alcohol
# 4                       Alcohol
# ...                         ...
# 1185671                Diabetes
# ...

# %%
cdi_edit_3 = cdi_edit_2.assign(patient_count=pd.to_numeric(cdi_edit_2['DataValue'], errors='coerce') / 10)

# %%
cdi_edit_3.head()
# Out:
#    YearStart  YearEnd LocationAbbr    LocationDesc                   Topic  \
# 0       2010     2010           OR          Oregon  Cardiovascular Disease
# 1       2019     2019           AZ         Arizona                 Alcohol
# 2       2019     2019           OH            Ohio                 Alcohol
# 3       2019     2019           US   United States                 Alcohol
# 4       2015     2015           VI  Virgin Islands                 Alcohol
#
#                        Question  Response DataValueUnit DataValue  \
# 0  Mortality from heart failure       NaN           NaN        30
# 1       Alcohol use among youth       NaN             %      29.5
# 2       Alcohol use among youth       NaN             %      22.5
# 3       Alcohol use among youth       NaN             %      13.9
# 4       Alcohol use among youth       NaN             %       NaN
#
#    DataValueAlt  ... ResponseID LocationID TopicID QuestionID DataValueTypeID  \
# ...

# %%
cdi_edit_3.to_csv('C:/Users/eykin/Desktop/Eddie Documentsls/projects/Chronic_disease_capstone/data/cdi_cleaned_add_latlong.csv')

# %%
counts_stratification_category = cdi_edit_2['StratificationCategory1'].value_counts().reset_index()
counts_stratification_category.columns = ['StratificationCategory1', 'Count']
stratification_category_counts = pd.DataFrame(counts_stratification_category)
stratification_category_counts
# Out:
#   StratificationCategory1   Count
# 0          Race/Ethnicity  738388
# 1                  Gender  280956
# 2                 Overall  166332

# %%
counts_stratification = cdi_edit_2['Stratification1'].value_counts().reset_index()
counts_stratification.columns = ['Stratification1', 'Count']
stratification_counts = pd.DataFrame(counts_stratification)
stratification_counts
# Out:
#                      Stratification1   Count
# 0                            Overall  166332
# 1                White, non-Hispanic  147244
# 2                           Hispanic  147199
# 3                Black, non-Hispanic  146984
# 4                             Female  140479
# 5                               Male  140477
# 6          Multiracial, non-Hispanic   85241
# 7                Other, non-Hispanic   85241
# 8   American Indian or Alaska Native   63150
# 9          Asian or Pacific Islander   60062
# 10               Asian, non-Hispanic    3267

# %%
data = pd.read_csv(r'c:\Users\eykin\Desktop\Eddie Documentsls\projects\Chronic_disease_capstone\data\PLACES__Local_Data_for_Better_Health__County_Data_2023_release_20240222.csv')

# %%
data4 = data.assign(InstancePerPopulation=1 / data['TotalPopulation'])

# %%
data4.head()
# Out:
#    Year StateAbbr StateDesc LocationName DataSource         Category  \
# 0  2021        GA   Georgia         Ware      BRFSS  Health Outcomes
# 1  2021        IN   Indiana         Ohio      BRFSS  Health Outcomes
# 2  2021        IN   Indiana         Owen      BRFSS  Health Outcomes
# 3  2021        IA      Iowa         Iowa      BRFSS  Health Outcomes
# 4  2021        IA      Iowa       Marion      BRFSS  Health Outcomes
#
#                                Measure Data_Value_Unit   Data_Value_Type  \
# 0  Stroke among adults aged >=18 years               %  Crude prevalence
# 1  Stroke among adults aged >=18 years               %  Crude prevalence
# 2  Stroke among adults aged >=18 years               %  Crude prevalence
# 3  Stroke among adults aged >=18 years               %  Crude prevalence
# 4  Stroke among adults aged >=18 years               %  Crude prevalence
#
#    Data_Value  ...  Low_Confidence_Limit  High_Confidence_Limit  \
# ...

# %%
category_counts = data['Category'].value_counts().reset_index()
category_counts.columns = ['Category', 'Count']
category_counts
# Out:
#                 Category  Count
# 0        Health Outcomes  80136
# 1             Prevention  62344
# 2             Disability  43078
# 3  Health Risk Behaviors  24750
# 4          Health Status  18462

# %%
outcomes_data = data[data['Category'] == 'Health Outcomes'].reset_index()

outcomes_data
# Out:
#         index  Year StateAbbr   StateDesc LocationName DataSource  \
# 0           0  2021        GA     Georgia         Ware      BRFSS
# 1           1  2021        IN     Indiana         Ohio      BRFSS
# 2           2  2021        IN     Indiana         Owen      BRFSS
# 3           3  2021        IA        Iowa         Iowa      BRFSS
# 4           4  2021        IA        Iowa       Marion      BRFSS
# ...       ...   ...       ...         ...          ...        ...
# 80131  228758  2021        WA  Washington      Stevens      BRFSS
# 80132  228759  2021        WI   Wisconsin         Iron      BRFSS
# 80133  228760  2021        WI   Wisconsin       Monroe      BRFSS
# 80134  228764  2021        WI   Wisconsin   Green Lake      BRFSS
# 80135  228766  2021        WI   Wisconsin         Door      BRFSS
#
#               Category                                            Measure  \
# 0      Health Outcomes                Stroke among adults aged >=18 years
# ...

# %%
prevention_data = data[data['Category'] == 'Prevention'].reset_index()

prevention_data
# Out:
#         index  Year StateAbbr      StateDesc LocationName DataSource  \
# 0          16  2020        CA     California   Sacramento      BRFSS
# 1          19  2021        AR       Arkansas      Jackson      BRFSS
# 2          25  2020        AK         Alaska   Dillingham      BRFSS
# 3          26  2020        CA     California         Kern      BRFSS
# 4          34  2020        AR       Arkansas   Washington      BRFSS
# ...       ...   ...       ...            ...          ...        ...
# 62339  228745  2021        WA     Washington      Whatcom      BRFSS
# 62340  228748  2021        WI      Wisconsin    Jefferson      BRFSS
# 62341  228752  2020        WV  West Virginia      Braxton      BRFSS
# 62342  228757  2021        WA     Washington       Pierce      BRFSS
# 62343  228765  2021        WA     Washington        Lewis      BRFSS
#
#          Category                                            Measure  \
# ...

# %%
disability_data = data[data['Category'] == 'Disability'].reset_index()

disability_data
# Out:
#         index  Year StateAbbr      StateDesc LocationName DataSource  \
# 0          12  2021        AR       Arkansas       Benton      BRFSS
# 1          24  2021        AZ        Arizona      Cochise      BRFSS
# 2          30  2021        CA     California       Sutter      BRFSS
# 3          37  2021        AL        Alabama      Colbert      BRFSS
# 4          50  2021        AL        Alabama      Houston      BRFSS
# ...       ...   ...       ...            ...          ...        ...
# 43073  228743  2021        WY        Wyoming       Carbon      BRFSS
# 43074  228750  2021        WI      Wisconsin      Portage      BRFSS
# 43075  228751  2021        WI      Wisconsin      Burnett      BRFSS
# 43076  228763  2021        WY        Wyoming     Sublette      BRFSS
# 43077  228768  2021        WV  West Virginia       Cabell      BRFSS
#
#          Category                                            Measure  \
# ...

# %%
status_data = data[data['Category'] == 'Health Status'].reset_index()

status_data
# Out:
#         index  Year StateAbbr      StateDesc LocationName DataSource  \
# 0          22  2021        AK         Alaska  Bristol Bay      BRFSS
# 1          41  2021        AK         Alaska   Dillingham      BRFSS
# 2          63  2021        AL        Alabama     Randolph      BRFSS
# 3          75  2021        CA     California       Sonoma      BRFSS
# 4         100  2021        CA     California     Humboldt      BRFSS
# ...       ...   ...       ...            ...          ...        ...
# 18457  228710  2021        WI      Wisconsin     Florence      BRFSS
# 18458  228715  2021        WI      Wisconsin       Forest      BRFSS
# 18459  228755  2021        WA     Washington        Lewis      BRFSS
# 18460  228762  2021        WV  West Virginia       Monroe      BRFSS
# 18461  228769  2021        WV  West Virginia        Wayne      BRFSS
#
#             Category                                            Measure  \
# ...

# %%
data4.to_csv(r'c:\Users\eykin\Desktop\Eddie Documentsls\projects\Chronic_disease_capstone\data\cdi_cleaned_add_latlong2.csv')

# %%
data4.head()
# Out:
#    Year StateAbbr StateDesc LocationName DataSource         Category  \
# 0  2021        GA   Georgia         Ware      BRFSS  Health Outcomes
# 1  2021        IN   Indiana         Ohio      BRFSS  Health Outcomes
# 2  2021        IN   Indiana         Owen      BRFSS  Health Outcomes
# 3  2021        IA      Iowa         Iowa      BRFSS  Health Outcomes
# 4  2021        IA      Iowa       Marion      BRFSS  Health Outcomes
#
#                                Measure Data_Value_Unit   Data_Value_Type  \
# 0  Stroke among adults aged >=18 years               %  Crude prevalence
# 1  Stroke among adults aged >=18 years               %  Crude prevalence
# 2  Stroke among adults aged >=18 years               %  Crude prevalence
# 3  Stroke among adults aged >=18 years               %  Crude prevalence
# 4  Stroke among adults aged >=18 years               %  Crude prevalence
#
#    Data_Value  ...  Low_Confidence_Limit  High_Confidence_Limit  \
# ...

# %%
pulmonary.head()
# Out:
#    YearStart  YearEnd LocationAbbr  LocationDesc DataSource  \
# 0       2016     2016           OR        Oregon  SEDD; SID
# 1       2017     2017           OR        Oregon  SEDD; SID
# 2       2018     2018           PR   Puerto Rico  SEDD; SID
# 3       2017     2017           SD  South Dakota  SEDD; SID
# 4       2015     2015           TX         Texas  SEDD; SID
#
#                                    Topic  \
# 0  Chronic Obstructive Pulmonary Disease
# 1  Chronic Obstructive Pulmonary Disease
# 2  Chronic Obstructive Pulmonary Disease
# 3  Chronic Obstructive Pulmonary Disease
# 4  Chronic Obstructive Pulmonary Disease
#
#                                             Question  Response DataValueUnit  \
# 0  Hospitalization for chronic obstructive pulmon...       NaN           NaN
# 1  Hospitalization for chronic obstructive pulmon...       NaN           NaN
# 2  Hospitalization for chronic obstructive pulmon...       NaN           NaN
# ...

# %%
pulmonary2 = pulmonary.assign(InstancePerPopulation=1 / data['TotalPopulation'])

# %%
pulmonary2.head()
# Out:
#    YearStart  YearEnd LocationAbbr  LocationDesc DataSource  \
# 0       2016     2016           OR        Oregon  SEDD; SID
# 1       2017     2017           OR        Oregon  SEDD; SID
# 2       2018     2018           PR   Puerto Rico  SEDD; SID
# 3       2017     2017           SD  South Dakota  SEDD; SID
# 4       2015     2015           TX         Texas  SEDD; SID
#
#                                    Topic  \
# 0  Chronic Obstructive Pulmonary Disease
# 1  Chronic Obstructive Pulmonary Disease
# 2  Chronic Obstructive Pulmonary Disease
# 3  Chronic Obstructive Pulmonary Disease
# 4  Chronic Obstructive Pulmonary Disease
#
#                                             Question  Response DataValueUnit  \
# 0  Hospitalization for chronic obstructive pulmon...       NaN           NaN
# 1  Hospitalization for chronic obstructive pulmon...       NaN           NaN
# 2  Hospitalization for chronic obstructive pulmon...       NaN           NaN
# ...

# %%
pulmonary2.to_csv(r'c:\Users\eykin\Desktop\Eddie Documentsls\projects\Chronic_disease_capstone\data\pulmonarywithinstance.csv')

# %%
columns_to_sum = [2, 3, 4, 5, 6, 7, 8, 10, 14, 17, 19, 20, 21, 22, 23, 24, 26, 27, 28, 29, 30, 31]
sum_of_indicators = cdc_census.iloc[:, columns_to_sum].sum(axis=1)
cdc_census['bad_indicators_per_population'] = sum_of_indicators / cdc_census.iloc[:, 1]
cdc_census.head()
# Out:
#    CENSUS TRACT  2010 POPULATION  LACKING HEALTH INSURANCE  ARTHRITIS  \
# 0   22033004602             5679                     0.126      0.267
# 1   22033000300             1795                     0.238      0.280
# 2   22033003703             6230                     0.117      0.259
# 3   22033002000             3435                     0.077      0.266
# 4   22033004005             6005                     0.126      0.236
#
#    BINGE DRINKING  HIGH BLOOD PRESSURE  BLOOD PRESSURE MEDICINE  \
# 0           0.210                0.409                    0.774
# 1           0.171                0.509                    0.758
# 2           0.205                0.386                    0.781
# 3           0.217                0.362                    0.792
# 4           0.224                0.382                    0.764
#
#    CANCER (EXCLUDING SKIN CANCER)  ASTHMA  CERVICAL CANCER SCREENING  ...  \
# 0                           0.071   0.092                      0.859  ...
# ...

# %%
columns_to_sum = [9,11,12,13,15,16,18]
sum_of_indicators = cdc_census.iloc[:, columns_to_sum].sum(axis=1)
cdc_census['good_indicators_per_population'] = sum_of_indicators / cdc_census.iloc[:, 1]
cdc_census.head()
# Out:
#    CENSUS TRACT  2010 POPULATION  LACKING HEALTH INSURANCE  ARTHRITIS  \
# 0   22033004602             5679                     0.126      0.267
# 1   22033000300             1795                     0.238      0.280
# 2   22033003703             6230                     0.117      0.259
# 3   22033002000             3435                     0.077      0.266
# 4   22033004005             6005                     0.126      0.236
#
#    BINGE DRINKING  HIGH BLOOD PRESSURE  BLOOD PRESSURE MEDICINE  \
# 0           0.210                0.409                    0.774
# 1           0.171                0.509                    0.758
# 2           0.205                0.386                    0.781
# 3           0.217                0.362                    0.792
# 4           0.224                0.382                    0.764
#
#    CANCER (EXCLUDING SKIN CANCER)  ASTHMA  CERVICAL CANCER SCREENING  ...  \
# 0                           0.071   0.092                      0.859  ...
# ...

# %%
cdc_census.to_csv(r'c:\Users\eykin\Desktop\Eddie Documentsls\projects\Chronic_disease_capstone\data\cdc_per_population.csv')
